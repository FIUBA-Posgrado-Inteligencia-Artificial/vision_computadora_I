# %% [markdown]
# # Anotaciones en imágenes
#
# Funciones básicas para graficar líneas, círculos y texto

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

#Si queremos que las imágenes sean mostradas en una ventana emergente quitar el inline
# !pip install PyQt5
# %matplotlib qt
# Out:
# Collecting PyQt5
#   Downloading PyQt5-5.15.10-cp37-abi3-win_amd64.whl.metadata (2.2 kB)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5)
#   Downloading PyQt5_sip-12.13.0-cp312-cp312-win_amd64.whl.metadata (524 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Downloading PyQt5-5.15.10-cp37-abi3-win_amd64.whl (6.8 MB)
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/6.8 MB 1.3 MB/s eta 0:00:06
#    - -------------------------------------- 0.2/6.8 MB 2.5 MB/s eta 0:00:03
#    --- ------------------------------------ 0.5/6.8 MB 3.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/6.8 MB 4.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/6.8 MB 4.8 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/6.8 MB 5.1 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/6.8 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/6.8 MB 4.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/6.8 MB 4.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.1/6.8 MB 4.5 MB/s eta 0:00:02
#    ------------ --------------------------- 2.1/6.8 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 2.4/6.8 MB 4.3 MB/s eta 0:00:02
#    --------------- ------------------------ 2.7/6.8 MB 4.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.8/6.8 MB 4.5 MB/s eta 0:00:01
#    ------------------ --------------------- 3.2/6.8 MB 4.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.6/6.8 MB 4.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.8 MB 5.0 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.8 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.8 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.8/6.8 MB 5.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.1/6.8 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 5.3/6.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 5.5/6.8 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.8 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.1/6.8 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 6.4/6.8 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.8/6.8 MB 5.5 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/50.1 MB 18.6 MB/s eta 0:00:03
#     --------------------------------------- 0.7/50.1 MB 8.8 MB/s eta 0:00:06
#     --------------------------------------- 1.0/50.1 MB 9.1 MB/s eta 0:00:06
#     --------------------------------------- 1.2/50.1 MB 8.8 MB/s eta 0:00:06
#    - -------------------------------------- 1.6/50.1 MB 8.5 MB/s eta 0:00:06
#    - -------------------------------------- 1.9/50.1 MB 8.1 MB/s eta 0:00:06
#    - -------------------------------------- 2.1/50.1 MB 7.6 MB/s eta 0:00:07
#    - -------------------------------------- 2.5/50.1 MB 7.4 MB/s eta 0:00:07
#    -- ------------------------------------- 2.8/50.1 MB 7.4 MB/s eta 0:00:07
#    -- ------------------------------------- 3.2/50.1 MB 7.7 MB/s eta 0:00:07
#    -- ------------------------------------- 3.6/50.1 MB 7.6 MB/s eta 0:00:07
#    --- ------------------------------------ 3.9/50.1 MB 7.7 MB/s eta 0:00:07
#    --- ------------------------------------ 4.2/50.1 MB 7.5 MB/s eta 0:00:07
#    --- ------------------------------------ 4.7/50.1 MB 7.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.1/50.1 MB 7.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.6/50.1 MB 7.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 6.0/50.1 MB 8.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 6.2/50.1 MB 7.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.3/50.1 MB 7.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.5/50.1 MB 7.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 6.8/50.1 MB 7.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 7.1/50.1 MB 7.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 7.4/50.1 MB 7.2 MB/s eta 0:00:06
#    ------ --------------------------------- 7.7/50.1 MB 7.3 MB/s eta 0:00:06
#    ------ --------------------------------- 8.0/50.1 MB 7.2 MB/s eta 0:00:06
#    ------ --------------------------------- 8.5/50.1 MB 7.2 MB/s eta 0:00:06
#    ------- -------------------------------- 8.9/50.1 MB 7.3 MB/s eta 0:00:06
#    ------- -------------------------------- 9.2/50.1 MB 7.3 MB/s eta 0:00:06
#    ------- -------------------------------- 9.5/50.1 MB 7.3 MB/s eta 0:00:06
#    ------- -------------------------------- 9.8/50.1 MB 7.3 MB/s eta 0:00:06
#    -------- ------------------------------- 10.2/50.1 MB 7.3 MB/s eta 0:00:06
#    -------- ------------------------------- 10.7/50.1 MB 7.3 MB/s eta 0:00:06
#    -------- ------------------------------- 10.9/50.1 MB 7.3 MB/s eta 0:00:06
#    -------- ------------------------------- 11.2/50.1 MB 7.2 MB/s eta 0:00:06
#    --------- ------------------------------ 11.3/50.1 MB 7.3 MB/s eta 0:00:06
#    --------- ------------------------------ 11.6/50.1 MB 7.0 MB/s eta 0:00:06
#    --------- ------------------------------ 11
ta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
# Successfully installed PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
img = cv.imread('imgBloque1.bmp')
start = (350, 0)
end = (350, 410)
# Dibujo una línea
# line(imagen,inicio,fin,color,ancho_linea,tipo_linea)
cv.line(img, start, end, (0,0,0), 2, cv.LINE_AA)
cv.line(img, (250, 0), (350, 410), (0, 0, 255), 2, cv.LINE_AA)
plt.imshow(img[...,::-1])

# %%
img = cv.imread('imgBloque1.bmp')
altura, ancho, canales = img.shape
start_1 = (ancho // 2 , 0)
end_1 = (ancho // 2, altura)

start_2 = (0, altura // 2)
end_2 = (ancho, altura // 2)

# Dibujo una línea
# line(imagen,inicio,fin,color,ancho_linea,tipo_linea)
cv.line(img, start_1, end_1, (0,0,0), 2, cv.LINE_AA)
cv.line(img, start_2, end_2, (0,0,0), 2, cv.LINE_AA)
# cv.line(img, (250, 0), (350, 410), (0, 0, 255), 2, cv.LINE_AA)
plt.imshow(img[...,::-1])

# %% [markdown]
# #### Tipos de líneas
# Filled: cv.FILLED
# 4-connected line: cv.LINE_4
# 8-connected line: cv.LINE_8
# Antialiased line: cv.LINE_AA

# %% [markdown]
# ### Tambien podemos dibujar otras figuras geometricas:
# - rectángulos (cv.rectangle)
# - elipses (cv.ellipse)
# - círculos (cv.circle)
# - polígonos (cv.polylines)

# %% [markdown]
# ### Escribo texto en la imagen

# %%
# cv.putText(imagen,texto,posicion,fuente,escala,color,espesor,tipo_linea)
img = cv.imread('it_predator.png')

bbox_start = (652, 58)
bbox_end = (927, 690)
cv.rectangle(img, bbox_start, bbox_end, (0,0,255),2)
cv.putText(img,'Figura 86%', bbox_start, cv.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv.LINE_AA)
plt.imshow(img[...,::-1])
plt.show()

# %%
# cv.putText(imagen,texto,posicion,fuente,escala,color,espesor,tipo_linea)
img = cv.imread('it_predator.png')

bbox_start_1 = (652, 58)
bbox_end_1 = (927, 690)
cv.rectangle(img, bbox_start_1, bbox_end_1, (0,0,255),2)
cv.putText(img,'Figura 86%', bbox_start_1, cv.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv.LINE_AA)

bbox_start_2 = (50, 30)
bbox_end_2 = (380, 670)
cv.rectangle(img, bbox_start_2, bbox_end_2, (0,0,255),2)
cv.putText(img,'Figura 70%', bbox_start_2, cv.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2, cv.LINE_AA)

plt.imshow(img[...,::-1])
plt.show()

# %% [markdown]
# ### Ajuste de texto a una ROI

# %%
img = cv.imread('it_predator.png')

label = 'FIGURA 86%'
(label_width, label_height), _ = cv.getTextSize(label, cv.FONT_HERSHEY_SIMPLEX, 1, 2)
text_end = (bbox_start[0] + label_width, bbox_start[1] - label_height)

cv.rectangle(img, bbox_start, bbox_end, (0,0,255),2)
cv.rectangle(img, bbox_start, text_end, (0,0,0),-1)
cv.putText(img, label, bbox_start, cv.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2)

plt.imshow(img[...,::-1])
plt.show()
